# %% [markdown]
# # Emerging Tech Lab - Kinetic Opentrons Protocol

# %% [markdown]
# ## Kinetic protocol setup

# %%
from kinetic_opentrons_helpers import (
    log_step,
    build_target_wells,
    build_timepoint_map,
    validate_volume_for_p300,
    dispense_to_wells_with_tip_changes,
    set_robot_speeds,
    log_absolute_time_tick,
    log_reverse_dialdehyde_order,
    summarise_middle_replicate_finish_times,
)

import opentrons.execute
protocol = opentrons.execute.get_protocol_api("2.19") # Restarting the kernel again.

# Loading labware
plate_48 = protocol.load_labware(
    "greenaway_48_wellplate_3750ul",
    location = 2
)
plate_8 = protocol.load_labware(
    "greenaway_8_wellplate_20000ul",
    location = 3
)
pip_rack = protocol.load_labware(
    "opentrons_96_tiprack_300ul",
    location = 6
)

# Load Pipettes
pip_300 = protocol.load_instrument(
    "p300_single_gen2",
    "left", # Change "right" or "left" depending on which arm the 300 uL pipette is
    tip_racks = [pip_rack]
)

# -----------------------------
# User setup: liquid handling
# -----------------------------

# Optimised handling parameters for volatile organic solvent mixtures
ASPIRATE_RATE = 70          # uL/s
STANDARD_DISPENSE_RATE = 70 # uL/s
SLOW_DISPENSE_RATE = 10     # uL/s, used for dropwise dialdehyde addition
AIR_GAP_VOLUME = 15         # uL
MAX_DISPENSE = 200          # uL; two thirds of the P300 volume
PRE_WET_CYCLES = 3
PRE_WET_VOLUME = 180        # uL
TIP_CHANGE_INTERVAL = 3     # compromise: discard tip after every 3 target-well dispenses
TRANSFER_MODE = "fast"      # "fast" = one tip per reagent/solvent source; "accurate" = change tips regularly

pip_300.flow_rate.aspirate = ASPIRATE_RATE
pip_300.flow_rate.dispense = STANDARD_DISPENSE_RATE

# Speed up robot movement while keeping liquid-handling flow rates controlled.
# Rim-touching during pre-wetting is slowed separately inside the helper function.
set_robot_speeds(
    protocol=protocol,
    pipette=pip_300,
    pipette_default_speed=400,
)

# -----------------------------
# User setup: source locations
# -----------------------------

# 8-well source plate layout, can be changed if needed:
# A1: diamine in CHCl3
# A2: diamine in MeOH
# A3: diamine in 1:1 CHCl3/MeOH
# B1: dialdehyde in CHCl3
# B2: dialdehyde in MeOH
# B3: dialdehyde in 1:1 CHCl3/MeOH

SOLVENT_CONDITIONS = {
    "chloroform": {
        "diamine_source": plate_8["A1"],
        "dialdehyde_source": plate_8["B1"],
        "rows": ["A", "B", "C"],
    },
    "methanol": {
        "diamine_source": plate_8["A2"],
        "dialdehyde_source": plate_8["B2"],
        "rows": ["D", "E", "F"],
    },
    # Use this condition in place of one of the two above if needed.
    # The 48-well plate can fit two solvent conditions per run:
    # 8 time points x 3 repeats x 2 conditions = 48 wells.
    "chloroform_methanol_1to1": {
        "diamine_source": plate_8["A3"],
        "dialdehyde_source": plate_8["B3"],
        "rows": ["D", "E", "F"],
    },
}

# Select exactly two solvent conditions for this run.
# Example layout below:
#   chloroform: A1:C6
CONDITIONS_TO_RUN = ["chloroform"]

if len(CONDITIONS_TO_RUN) == 0:
    raise ValueError("Select at least one solvent condition to run.")
# Time-point labels for records only.
# The robot does not wait for these time intervals; instead, the dialdehyde addition order
# is arranged so that later sampling time points are started first and earlier time points last.
# This makes manual sampling/quenching easier: the 0 min samples are started closest to work-up.
TIMEPOINTS_MIN = [5, 15, 25, 35, 45, 55, 65, 75]

if not 1 <= len(TIMEPOINTS_MIN) <= 8:
    raise ValueError("TIMEPOINTS_MIN must contain between 1 and 8 time points to fit columns 1-8 of the 48-well plate.")

# -----------------------------
# User setup: dispense volumes
# -----------------------------

# Enter the calculated volume for each stock solution per reaction vial.
# These volumes are applied to every replicate/time-point well in this run.
volume_of_diamine = 1000      # uL per well
volume_of_dialdehyde = 200   # uL per well

# -----------------------------
# Build and validate the plate map
# -----------------------------

validate_volume_for_p300(volume_of_diamine, "Diamine", protocol=protocol)
validate_volume_for_p300(volume_of_dialdehyde, "Dialdehyde", protocol=protocol)

all_target_wells = []

for condition_name in CONDITIONS_TO_RUN:
    if condition_name not in SOLVENT_CONDITIONS:
        raise ValueError(f"Unknown solvent condition: {condition_name}")

    condition = SOLVENT_CONDITIONS[condition_name]
    condition["target_wells"] = build_target_wells(
        condition["rows"],
        n_columns=len(TIMEPOINTS_MIN),
    )
    condition["timepoint_map"] = build_timepoint_map(
        condition["rows"],
        TIMEPOINTS_MIN,
    )

    wells = condition["target_wells"]
    all_target_wells.extend(wells)

    log_step(protocol, f"Condition: {condition_name}")
    for entry in condition["timepoint_map"]:
        log_step(protocol,
            f"  {entry['time_min']} min, column {entry['column']}: {', '.join(entry['wells'])}"
        )

if len(set(all_target_wells)) != len(all_target_wells):
    raise ValueError("Duplicate target wells detected. Check the selected solvent-condition layouts.")
# Out:
# /data/robot_settings.json not found. Loading defaults
# Failed to initialize character device, will not be able to control gpios (lights, button, smoothiekill, smoothie reset). Only one connection can be made to the gpios at a time. If you need to control gpios, first stop the robot server with systemctl stop opentrons-robot-server. Until you restart the server with systemctl start opentrons-robot-server, you will be unable to control the robot using the Opentrons app.
# /data/deck_calibration.json not found. Loading defaults
# Set pipette default movement speed to 400 mm/s.
# Warning: Diamine volume is 1000 uL and will be split into multiple dispenses of <= 200 uL.
# Condition: chloroform
#   5 min, column 1: A1, B1, C1
#   15 min, column 2: A2, B2, C2
#   25 min, column 3: A3, B3, C3
#   35 min, column 4: A4, B4, C4
#   45 min, column 5: A5, B5, C5
#   55 min, column 6: A6, B6, C6
#   65 min, column 7: A7, B7, C7
#   75 min, column 8: A8, B8, C8

# %%
# -----------------------------
# Basic OT-2 sanity test
# -----------------------------

protocol.home()

log_step(protocol, "Starting basic OT-2 sanity test.")

pip_300.drop_tip()

# Test tip pickup/drop
pip_300.pick_up_tip()
log_step(protocol, "Picked up one tip successfully.")

# Test movement to source and target wells
pip_300.move_to(plate_8["A1"].top())
log_step(protocol, "Moved to source plate_8 A1 top.")

pip_300.move_to(plate_8["B1"].top())
log_step(protocol, "Moved to source plate_8 B1 top.")



pip_300.move_to(plate_48["A1"].top())
log_step(protocol, "Moved to target well A1 top.")

pip_300.move_to(plate_48["C8"].top())
log_step(protocol, "Moved to target well C8 top.")

pip_300.drop_tip()
log_step(protocol, "Dropped tip successfully.")

protocol.home()
log_step(protocol, "Basic OT-2 sanity test complete.")
# Out:
# Starting basic OT-2 sanity test.
# Picked up one tip successfully.
# Moved to source plate_8 A1 top.
# Moved to source plate_8 B1 top.
# Moved to target well A1 top.
# Moved to target well C8 top.
# Dropped tip successfully.
# Basic OT-2 sanity test complete.

# %% [markdown]
# ## Automated kinetic reaction setup

# %%
# -----------------------------
# Automated kinetic reaction setup
# Correct addition order:
#   1. diamine solution
#   2. dialdehyde solution, slow/dropwise
# -----------------------------

# Store dispense records for later inspection.
diamine_dispense_records = {}
dialdehyde_dispense_records = {}
kinetic_start_time_summaries = {}

# Add diamine solution to all wells first.
# This does not start the imine reaction until the dialdehyde is later added.
for condition_name in CONDITIONS_TO_RUN:
    condition = SOLVENT_CONDITIONS[condition_name]
    diamine_dispense_records[condition_name] = dispense_to_wells_with_tip_changes(
        pipette=pip_300,
        protocol=protocol,
        plate=plate_48,
        source_well=condition["diamine_source"],
        target_well_names=condition["target_wells"],
        total_volume=volume_of_diamine,
        dispense_rate=STANDARD_DISPENSE_RATE,
        reagent_name=f"diamine stock ({condition_name})",
        tip_change_interval=TIP_CHANGE_INTERVAL,
        transfer_mode=TRANSFER_MODE,
        max_dispense=MAX_DISPENSE,
        air_gap_volume=AIR_GAP_VOLUME,
        pre_wet_cycles=PRE_WET_CYCLES,
        pre_wet_volume=PRE_WET_VOLUME,
        log_each_dispense_time=False,
        log_absolute_time=False,
    )

# Refined kinetic timing logic:
# The reaction starts when dialdehyde is added.
# For easier manual sampling/quenching, start the longest nominal time points first
# and the shortest/0 min time points last.
for condition_name in CONDITIONS_TO_RUN:
    condition = SOLVENT_CONDITIONS[condition_name]

    dialdehyde_ordered_wells = log_reverse_dialdehyde_order(
        condition["timepoint_map"],
        protocol=protocol,
    )

    log_absolute_time_tick(protocol, f"Starting dialdehyde addition for {condition_name}.")

    dialdehyde_dispense_records[condition_name] = dispense_to_wells_with_tip_changes(
        pipette=pip_300,
        protocol=protocol,
        plate=plate_48,
        source_well=condition["dialdehyde_source"],
        target_well_names=dialdehyde_ordered_wells,
        total_volume=volume_of_dialdehyde,
        dispense_rate=SLOW_DISPENSE_RATE,
        reagent_name=f"dialdehyde stock ({condition_name})",
        tip_change_interval=TIP_CHANGE_INTERVAL,
        transfer_mode=TRANSFER_MODE,
        max_dispense=MAX_DISPENSE,
        air_gap_volume=AIR_GAP_VOLUME,
        pre_wet_cycles=PRE_WET_CYCLES,
        pre_wet_volume=PRE_WET_VOLUME,
        log_each_dispense_time=True,
        log_absolute_time=True,
    )

    kinetic_start_time_summaries[condition_name] = summarise_middle_replicate_finish_times(
        dispense_records=dialdehyde_dispense_records[condition_name],
        timepoint_map=condition["timepoint_map"],
        protocol=protocol,
    )

    log_absolute_time_tick(protocol, f"Finished dialdehyde addition for {condition_name}.")

# Reset dispense rate and home the robot.
pip_300.flow_rate.dispense = STANDARD_DISPENSE_RATE

log_step(protocol, "Kinetic start-time summary by condition:")
for condition_name, summary in kinetic_start_time_summaries.items():
    log_step(protocol, f"Condition: {condition_name}")
    for record in summary:
        log_step(
            protocol,
            f"  nominal {record['time_min']} min | representative well {record['representative_well']} | "
            f"dispense order {record['dispense_order_index']} | start timestamp {record['finish_timestamp']}"
        )

protocol.home()
# Out:
# Fast mode enabled for diamine stock (chloroform): using one tip for this reagent/solvent source.
# Picked up tip 1 for diamine stock (chloroform).
# Adding 1000 uL diamine stock (chloroform) to A1.
# Adding 1000 uL diamine stock (chloroform) to B1.
# Adding 1000 uL diamine stock (chloroform) to C1.
# Adding 1000 uL diamine stock (chloroform) to A2.
# Adding 1000 uL diamine stock (chloroform) to B2.
# Adding 1000 uL diamine stock (chloroform) to C2.
# Adding 1000 uL diamine stock (chloroform) to A3.
# Adding 1000 uL diamine stock (chloroform) to B3.
# Adding 1000 uL diamine stock (chloroform) to C3.
# Adding 1000 uL diamine stock (chloroform) to A4.
# Adding 1000 uL diamine stock (chloroform) to B4.
# Adding 1000 uL diamine stock (chloroform) to C4.
# Adding 1000 uL diamine stock (chloroform) to A5.
# Adding 1000 uL diamine stock (chloroform) to B5.
# Adding 1000 uL diamine stock (chloroform) to C5.
# Adding 1000 uL diamine stock (chloroform) to A6.
# Adding 1000 uL diamine stock (chloroform) to B6.
# Adding 1000 uL diamine stock (chloroform) to C6.
# Adding 1000 uL diamine stock (chloroform) to A7.
# Adding 1000 uL diamine stock (chloroform) to B7.
# Adding 1000 uL diamine stock (chloroform) to C7.
# Adding 1000 uL diamine stock (chloroform) to A8.
# Adding 1000 uL diamine stock (chloroform) to B8.
# Adding 1000 uL diamine stock (chloroform) to C8.
# Dropped tip 1 after 24 target-well dispenses for diamine stock (chloroform).
# Reverse dialdehyde order: nominal 75 min time point, column 8 -> A8, B8, C8.
# Reverse dialdehyde order: nominal 65 min time point, column 7 -> A7, B7, C7.
# Reverse dialdehyde order: nominal 55 min time point, column 6 -> A6, B6, C6.
# Reverse dialdehyde order: nominal 45 min time point, column 5 -> A5, B5, C5.
# Reverse dialdehyde order: nominal 35 min time point, column 4 -> A4, B4, C4.
# Reverse dialdehyde order: nominal 25 min time point, column 3 -> A3, B3, C3.
# Reverse dialdehyde order: nominal 15 min time point, column 2 -> A2, B2, C2.
# Reverse dialdehyde order: nominal 5 min time point, column 1 -> A1, B1, C1.
# [2026-05-22 09:13:12] Starting dialdehyde addition for chloroform.
# Fast mode enabled for dialdehyde stock (chloroform): using one tip for this reagent/solvent source.
# Picked up tip 1 for dialdehyde stock (chloroform).
# [2026-05-22 09:13:58] Starting dispense: 200 uL dialdehyde stock (chloroform) to A8.
# [2026-05-22 09:14:29] Finished dispense: 200 uL dialdehyde stock (chloroform) to A8.
# [2026-05-22 09:14:29] Starting dispense: 200 uL dialdehyde stock (chloroform) to B8.
# [2026-05-22 09:15:00] Finished dispense: 200 uL dialdehyde stock (chloroform) to B8.
# [2026-05-22 09:15:00] Starting dispense: 200 uL dialdehyde stock (chloroform) to C8.
# [2026-05-22 09:15:32] Finished dispense: 200 uL dialdehyde stock (chloroform) to C8.
# [2026-05-22 09:15:32] Starting dispense: 200 uL dialdehyde stock (chloroform) to A7.
# [2026-05-22 09:16:03] Finished dispense: 200 uL dialdehyde stock (chloroform) to A7.
# [2026-05-22 09:16:03] Starting dispense: 200 uL dialdehyde stock (chloroform) to B7.
# [2026-05-22 09:16:34] Finished dispense: 200 uL dialdehyde stock (chloroform) to B7.
# [2026-05-22 09:16:34] Starting dispense: 200 uL dialdehyde stock (chloroform) to C7.
# [2026-05-22 09:17:06] Finished dispense: 200 uL dialdehyde stock (chloroform) to C7.
# [2026-05-22 09:17:06] Starting dispense: 200 uL dialdehyde stock (chloroform) to A6.
# [2026-05-22 09:17:37] Finished dispense: 200 uL dialdehyde stock (chloroform) to A6.
# [2026-05-22 09:17:37] Starting dispense: 200 uL dialdehyde stock (chloroform) to B6.
# [2026-05-22 09:18:09] Finished dispense: 200 uL dialdehyde stock (chloroform) to B6.
# [2026-05-22 09:18:09] Starting dispense: 200 uL dialdehyde stock (chloroform) to C6.
# [2026-05-22 09:18:40] Finished dispense: 200 uL dialdehyde stock (chloroform) to C6.
# [2026-05-22 09:18:40] Starting dispense: 200 uL dialdehyde stock (chloroform) to A5.
# [2026-05-22 09:19:12] Finished dispense: 200 uL dialdehyde stock (chloroform) to A5.
# [2026-05-22 09:19:12] Starting dispense: 200 uL dialdehyde stock (chloroform) to B5.
# [2026-05-22 09:19:43] Finished dispense: 200 uL dialdehyde stock (chloroform) to B5.
# [2026-05-22 09:19:43] Starting dispense: 200 uL dialdehyde stock (chloroform) to C5.
# [2026-05-22 09:20:15] Finished dispense: 200 uL dialdehyde stock (chloroform) to C5.
# [2026-05-22 09:20:15] Starting dispense: 200 uL dialdehyde stock (chloroform) to A4.
# [2026-05-22 09:20:47] Finished dispense: 200 uL dialdehyde stock (chloroform) to A4.
# [2026-05-22 09:20:47] Starting dispense: 200 uL dialdehyde stock (chloroform) to B4.
# [2026-05-22 09:21:18] Finished dispense: 200 uL dialdehyde stock (chloroform) to B4.
# [2026-05-22 09:21:18] Starting dispense: 200 uL dialdehyde stock (chloroform) to C4.
# [2026-05-22 09:21:50] Finished dispense: 200 uL dialdehyde stock (chloroform) to C4.
# [2026-05-22 09:21:50] Starting dispense: 200 uL dialdehyde stock (chloroform) to A3.
# [2026-05-22 09:22:22] Finished dispense: 200 uL dialdehyde stock (chloroform) to A3.
# [2026-05-22 09:22:22] Starting dispense: 200 uL dialdehyde stock (chloroform) to B3.
# [2026-05-22 09:22:53] Finished dispense: 200 uL dialdehyde stock (chloroform) to B3.
# [2026-05-22 09:22:53] Starting dispense: 200 uL dialdehyde stock (chloroform) to C3.
# [2026-05-22 09:23:25] Finished dispense: 200 uL dialdehyde stock (chloroform) to C3.
# [2026-05-22 09:23:25] Starting dispense: 200 uL dialdehyde stock (chloroform) to A2.
# [2026-05-22 09:23:57] Finished dispense: 200 uL dialdehyde stock (chloroform) to A2.
# [2026-05-22 09:23:57] Starting dispense: 200 uL dialdehyde stock (chloroform) to B2.
# [2026-05-22 09:24:29] Finished dispense: 200 uL dialdehyde stock (chloroform) to B2.
# [2026-05-22 09:24:29] Starting dispense: 200 uL dialdehyde stock (chloroform) to C2.
# [2026-05-22 09:25:00] Finished dispense: 200 uL dialdehyde stock (chloroform) to C2.
# [2026-05-22 09:25:00] Starting dispense: 200 uL dialdehyde stock (chloroform) to A1.
# [2026-05-22 09:25:32] Finished dispense: 200 uL dialdehyde stock (chloroform) to A1.
# [2026-05-22 09:25:32] Starting dispense: 200 uL dialdehyde stock (chloroform) to B1.
# [2026-05-22 09:26:04] Finished dispense: 200 uL dialdehyde stock (chloroform) to B1.
# [2026-05-22 09:26:04] Starting dispense: 200 uL dialdehyde stock (chloroform) to C1.
# [2026-05-22 09:26:36] Finished dispense: 200 uL dialdehyde stock (chloroform) to C1.
# Dropped tip 1 after 24 target-well dispenses for dialdehyde stock (chloroform).
# Representative kinetic start for nominal 5 min time point = B1 (dispense order 23), finished dialdehyde dispense at 2026-05-22 09:26:04.
# Representative kinetic start for nominal 15 min time point = B2 (dispense order 20), finished dialdehyde dispense at 2026-05-22 09:24:29.
# Representative kinetic start for nominal 25 min time point = B3 (dispense order 17), finished dialdehyde dispense at 2026-05-22 09:22:53.
# Representative kinetic start for nominal 35 min time point = B4 (dispense order 14), finished dialdehyde dispense at 2026-05-22 09:21:18.
# Representative kinetic start for nominal 45 min time point = B5 (dispense order 11), finished dialdehyde dispense at 2026-05-22 09:19:43.
# Representative kinetic start for nominal 55 min time point = B6 (dispense order 8), finished dialdehyde dispense at 2026-05-22 09:18:09.
# Representative kinetic start for nominal 65 min time point = B7 (dispense order 5), finished dialdehyde dispense at 2026-05-22 09:16:34.
# Representative kinetic start for nominal 75 min time point = B8 (dispense order 2), finished dialdehyde dispense at 2026-05-22 09:15:00.
# [2026-05-22 09:26:49] Finished dialdehyde addition for chloroform.
# Kinetic start-time summary by condition:
# Condition: chloroform
#   nominal 5 min | representative well B1 | dispense order 23 | start timestamp 2026-05-22 09:26:04
#   nominal 15 min | representative well B2 | dispense order 20 | start timestamp 2026-05-22 09:24:29
#   nominal 25 min | representative well B3 | dispense order 17 | start timestamp 2026-05-22 09:22:53
#   nominal 35 min | representative well B4 | dispense order 14 | start timestamp 2026-05-22 09:21:18
#   nominal 45 min | representative well B5 | dispense order 11 | start timestamp 2026-05-22 09:19:43
#   nominal 55 min | representative well B6 | dispense order 8 | start timestamp 2026-05-22 09:18:09
#   nominal 65 min | representative well B7 | dispense order 5 | start timestamp 2026-05-22 09:16:34
#   nominal 75 min | representative well B8 | dispense order 2 | start timestamp 2026-05-22 09:15:00
